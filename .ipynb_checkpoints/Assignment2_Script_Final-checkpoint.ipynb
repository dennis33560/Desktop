# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
bank_p = 'bank-additional-full.csv'

# %%
bank = pd.read_csv(bank_p, sep=';', decimal='.')

# %%
bank3= bank[['age', 'job']]
# Out:
# /Users/Dennis/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
bank3.head()
# Out:
#    age        job
# 0   56  housemaid
# 1   57   services
# 2   37   services
# 3   40     admin.
# 4   56   services

# %%
bank3.columns
# Out:
# Index([u'age', u'job'], dtype='object')

# %%
#Preview the dataset to ensure it matches specifications
bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
#Check that the dimensions of the dataset match the original dataset
bank.shape
# Out:
# (41188, 21)

# %%
#Viewing the datatypes of each column
bank.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
#Checking for missing values
bank.isnull().sum()
#No missing values
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#View summary statistics of continuous variables
bank.describe().round(2)
# Out:
#             age  duration  campaign     pdays  previous  emp.var.rate  \
# count  41188.00  41188.00  41188.00  41188.00  41188.00      41188.00
# mean      40.02    258.29      2.57    962.48      0.17          0.08
# std       10.42    259.28      2.77    186.91      0.49          1.57
# min       17.00      0.00      1.00      0.00      0.00         -3.40
# 25%       32.00    102.00      1.00    999.00      0.00         -1.80
# 50%       38.00    180.00      2.00    999.00      0.00          1.10
# 75%       47.00    319.00      3.00    999.00      0.00          1.40
# max       98.00   4918.00     56.00    999.00      7.00          1.40
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# count        41188.00       41188.00   41188.00     41188.00
# mean            93.58         -40.50       3.62      5167.04
# std              0.58           4.63       1.73        72.25
# min             92.20         -50.80       0.63      4963.60
# ...

# %%
#View summary statistics of categorical attributes
bank.describe(include = 'object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
#View all types of values in categorical variables
for col in bank.columns:
    if (bank[col].dtype.name == 'object'):
        print (bank[col].name)
        print (bank[col].unique())
#No observable spelling or white space erros in the dataset. No further preprocessing required.
# Out:
# job
# ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
# marital
# ['married' 'single' 'divorced' 'unknown']
# education
# ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
# default
# ['no' 'unknown' 'yes']
# housing
# ['no' 'yes' 'unknown']
# loan
# ['no' 'yes' 'unknown']
# contact
# ['telephone' 'cellular']
# month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr' 'sep']
# day_of_week
# ['mon' 'tue' 'wed' 'thu' 'fri']
# poutcome
# ['nonexistent' 'failure' 'success']
# y
# ['no' 'yes']

# %%
#Setting constants for easier visualisations
barcolor = {'#7B68EE','#FF8C00','#00FF00','#DC143C','#8A2BE2','#8B0000','#FF69B4','#FFA07A','#00FF7F','#00FFFF','#191970','#708090'}
piecolor = {'#BA55D3', '#DA70D6', '#DDA0DD'}
histcolor = {'#F08080'}

#Setting up methods for easier visualisation

#Bar plot method
def BarPlot(x,y):
  plt.figure(figsize=(12,6))
  plt.title("Figure " + str(y) + " : Bar Plot of " + x.capitalize() + " Variable", fontsize = 16)
  plt.xlabel(x.capitalize(), fontsize = 16)
  plt.ylabel("Frequency", fontsize = 16)
  plt.style.use('seaborn-whitegrid')
  ax = bank[x].value_counts(normalize = True).plot(kind = "bar", edgecolor = 'black', fontsize = 14, color = barcolor)
  plt.show()

#Pie chart method    
def Pie(x,y):
  plt.figure(figsize=(6,6))
  plt.title("Figure " + str(y) + " : Pie Chart of " + x.capitalize() + " Variable", fontsize = 16)
  plt.xlabel('', fontsize='large')
  ax = bank[x].value_counts(normalize = True).plot(kind = "pie", startangle=90, 
                                                   colors = piecolor, autopct='%1.1f%%', 
                                                   pctdistance=0.7, labeldistance=1.2,
                                                   textprops={'fontsize': 14}, wedgeprops={"edgecolor":"k"})
  plt.show()

#Histogram method
def Hist(x,y):
  plt.figure(figsize=(12,6))
  plt.title("Figure " + str(y) + " : Histogram of " + x.capitalize() + " Variable", fontsize = 16)
  plt.xlabel(x.capitalize())
  plt.ylabel("Frequency")
  plt.style.use('seaborn-whitegrid')
  ax = bank[x].plot(kind = "hist", edgecolor = 'black', color = histcolor)
  plt.show()

#Histogram method for continuous variable with y variable
def hist2(x,y):
  plt.figure(figsize=(12,6))
  data1 = bank.loc[bank['y']=="no", x] 
  data2 = bank.loc[bank['y']=="yes", x] 
  plt.hist(data1, alpha = 0.3, bins = 30, edgecolor = 'black', color = '#00FFFF')
  plt.hist(data2, bins = 30, edgecolor = 'black', color = '#F08080')
  plt.title("Figure " + str(y) + " : Term Deposit by " + x.capitalize(), fontsize = 16)
  plt.xlabel(x.capitalize(), fontsize = 16)
  plt.ylabel("Frequency", fontsize = 16)
  plt.style.use('seaborn-whitegrid')
  plt.legend(bank['y'].unique(), bbox_to_anchor=(1.05, 1), loc=2, fontsize = 16)

# %%
#We will look at 5 categorical variables
#View visualisation of Job variable
BarPlot('job',1)

# %%
#Visualisation of education variable
BarPlot('education', 2)

# %%
#View visualisation of housing variable
Pie('housing',3)

# %%
#View visualisation of loan variable
Pie('loan',4)

# %%
#View visualisation of contact variable
Pie('y',5)

# %%
#Now we will look at 5 continuous variables
#View visualisation of age variable
Hist('age',6)

# %%
#View visualisation of duration variable
Hist('duration',7)

# %%
#View visualisation of campaign variable
Hist('campaign', 8)

# %%
#View visualisation of consumer price index variable
BarPlot('marital', 9)

# %%
#View visualisation of consumer confidence index variable
BarPlot('poutcome',10)

# %%
#Since the desired outcome is the variable y, we will be comparing the next few variables with y for hypothesis testing.
hist2('age', 11)

# %%
yCounts = (bank.groupby('job')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.job.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('Job', fontsize = 16)
ax.set_title("Figure 12: Term deposit by Job", fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.job.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
yCounts = (bank.groupby('marital')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.marital.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('Marital', fontsize = 16)
ax.set_title("Figure 13"  +': Term deposit by Marital' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.marital.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
yCounts = (bank.groupby('education')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.education.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('Education', fontsize = 16)
ax.set_title("Figure 14"  +': Term deposit by Education' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.education.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
yCounts = (bank.groupby('poutcome')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.poutcome.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('poutcome', fontsize = 16)
ax.set_title("Figure 15"  +': Term deposit by poutcome' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.poutcome.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
yCounts = (bank.groupby('loan')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.loan.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('loan', fontsize = 16)
ax.set_title("Figure 16"  +': Term deposit by loan' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.loan.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
yCounts = (bank.groupby('housing')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.housing.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind, data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('housing', fontsize = 16)
ax.set_title("Figure 17"  +': Term deposit by Housing' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.housing.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
hist2('pdays', 19)

# %%
yCounts = (bank.groupby('contact')['y'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index())
data1 = yCounts.loc[yCounts['y']=='no','Percentage']
data2 = yCounts.loc[yCounts['y']=='yes','Percentage'] 
ind = np.arange(len(bank.contact.unique())) 
width = 0.30
fig, ax = plt.subplots(figsize = (12,6))
d1 = ax.bar(ind + width, data1, width, color='#00FFFF', edgecolor = 'black')
d2 = ax.bar(ind , data2, width, color='#F08080', edgecolor = 'black')
ax.set_ylabel('Percent', fontsize = 16)
ax.set_xlabel('contact', fontsize = 16)
ax.set_title("Figure 19"  +': Term deposit by Contact' , fontsize = 16)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((bank.contact.unique()), rotation = 90, fontsize = 16)
ax.legend((d1[0], d2[0]), ('no', 'yes'), bbox_to_anchor=(1.05, 1), fontsize = 16) 
plt.show()

# %%
hist2('campaign', 20)

# %%
#Import packages for classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import preprocessing
import math
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
#Changing categorical variables to numerical
for column in bank2.columns:
    if bank2[column].dtype == type(object):
        le = preprocessing.LabelEncoder()
        bank2[column] = le.fit_transform(bank2[column])

# %%
#Start of kNN
#Setting constants for x and y
y = bank2.y
x = bank2.drop(['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'month', 'day_of_week'], axis=1)

# %%
#Create method for KNearestNeighbours test data split input
def knn(num1, num2, w, m, num3):
    clf = KNeighborsClassifier(n_neighbors = num2, weights = w , metric = m , p = num3)
    fit = clf.fit(X_train, y_train)
    y_pre = fit.predict(X_test)
    cm = confusion_matrix(y_test, y_pre)
    print("Confusion Matrix with Test Split of " + str(num1) + "%:")
    print(cm)
    print
    print("Classification Report with Test Split of " + str(num1) + "%:")
    print classification_report(y_test,y_pre)

# %%
#50% test split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5,random_state=0)

#Choosing n_neighbours
print(math.sqrt(len(y_test)))
#We will choose the nearest odd number of the square root of the y_test length for n_neighbours

#Choosing weight
#We will use a distance weight as that is more applicable to the dataset based on the outcome we are predicting

#Choosing the metric
#We will stick with the default minkowski metric

#Choosing the p value
#The default value of 2 will be chosen as a low value is ideal to keep all features relevant
knn(50, 144, 'distance', 'minkowski', 2)
# Out:
# 143.506097431
# Confusion Matrix with Test Split of 50%:
# [[17864   427]
#  [ 1469   834]]
#
# Classification Report with Test Split of 50%:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     18291
#            1       0.66      0.36      0.47      2303
#
#    micro avg       0.91      0.91      0.91     20594
#    macro avg       0.79      0.67      0.71     20594
# weighted avg       0.89      0.91      0.90     20594

# %%
#40% test split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.4,random_state=0)

#Choosing n_neighbours
print(math.sqrt(len(y_test)))
#We will choose the nearest odd number of the square root of the y_test length for n_neighbours

#Choosing weight
#We will use a distance weight as that is more applicable to the dataset based on the outcome we are predicting

#Choosing the metric
#We will stick with the default minkowski metric

#Choosing the p value
#The default value of 2 will be chosen as a low value is ideal to keep all features relevant
knn(40, 127, 'distance', 'minkowski', 2)
# Out:
# 128.358871918
# Confusion Matrix with Test Split of 40%:
# [[14318   337]
#  [ 1160   661]]
#
# Classification Report with Test Split of 40%:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     14655
#            1       0.66      0.36      0.47      1821
#
#    micro avg       0.91      0.91      0.91     16476
#    macro avg       0.79      0.67      0.71     16476
# weighted avg       0.90      0.91      0.90     16476

# %%
#20% test split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

#Choosing n_neighbours
print(math.sqrt(len(y_test)))
#We will choose the nearest odd number of the square root of the y_test length for n_neighbours

#Choosing weight
#We will use a distance weight as that is more applicable to the dataset based on the outcome we are predicting

#Choosing the metric
#We will stick with the default minkowski metric

#Choosing the p value
#The default value of 2 will be chosen as a low value is ideal to keep all features relevant
knn(20, 91, 'distance', 'minkowski', 2)
# Out:
# 90.7634287585
# Confusion Matrix with Test Split of 20%:
# [[7147  172]
#  [ 579  340]]
#
# Classification Report with Test Split of 20%:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      7319
#            1       0.66      0.37      0.48       919
#
#    micro avg       0.91      0.91      0.91      8238
#    macro avg       0.79      0.67      0.71      8238
# weighted avg       0.90      0.91      0.90      8238

# %%
#Start of DT
def dt(num):
    y = bank2.y
    x = bank2.drop(['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y', 'month', 'day_of_week'], axis=1)
    X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=num,random_state=0)
    clf = DecisionTreeClassifier()
    fit = clf.fit(X_train, y_train)
    y_pre = fit.predict(X_test)
    cm = confusion_matrix(y_test, y_pre)
    print("Confusion Matrix with Test Split of " + str(num) + ":")
    print(cm)
    print
    print("Classification Report with Test Split of " + str(num) + ":")
    print classification_report(y_test,y_pre)

# %%
dt(0.5)
# Out:
# Confusion Matrix with Test Split of 0.5:
# [[16772  1519]
#  [ 1325   978]]
#
# Classification Report with Test Split of 0.5:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     18291
#            1       0.39      0.42      0.41      2303
#
#    micro avg       0.86      0.86      0.86     20594
#    macro avg       0.66      0.67      0.66     20594
# weighted avg       0.87      0.86      0.86     20594

# %%
dt(0.4)
# Out:
# Confusion Matrix with Test Split of 0.4:
# [[13404  1251]
#  [ 1042   779]]
#
# Classification Report with Test Split of 0.4:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92     14655
#            1       0.38      0.43      0.40      1821
#
#    micro avg       0.86      0.86      0.86     16476
#    macro avg       0.66      0.67      0.66     16476
# weighted avg       0.87      0.86      0.86     16476

# %%
dt(0.2)
# Out:
# Confusion Matrix with Test Split of 0.2:
# [[6710  609]
#  [ 525  394]]
#
# Classification Report with Test Split of 0.2:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      7319
#            1       0.39      0.43      0.41       919
#
#    micro avg       0.86      0.86      0.86      8238
#    macro avg       0.66      0.67      0.67      8238
# weighted avg       0.87      0.86      0.86      8238

# %%
 X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.4,random_state=100)

# %%
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100,
                                  max_depth = None,min_samples_split=2,
                                  max_features=None,max_leaf_nodes = None)

# %%
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
y_pred = clf_entropy.predict(X_test)

# %%
cm = confusion_matrix(y_test,y_pred)
print cm
# Out:
# [[13473  1144]
#  [ 1084   775]]

# %%
print classification_report(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92     14617
#            1       0.40      0.42      0.41      1859
#
#    micro avg       0.86      0.86      0.86     16476
#    macro avg       0.66      0.67      0.67     16476
# weighted avg       0.87      0.86      0.87     16476

# %%
with open('bank.dot', 'w') as f:
    f = tree.export_graphviz(clf_entropy, out_file=f, feature_names=x.columns, class_names= y, filled=True, rounded=True, special_characters=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a4bdf9ba1383> in <module>()
#       1 with open('bank.dot', 'w') as f:
# ----> 2     f = tree.export_graphviz(clf_entropy, out_file=f, feature_names=x.columns, class_names= y, filled=True, rounded=True, special_characters=True)
#
# /Users/Dennis/anaconda2/lib/python2.7/site-packages/sklearn/tree/export.pyc in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     457
#     458         # Now recurse the tree and add node & edge attributes
# --> 459         recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     460
#     461         # If required, draw leaf nodes at same depth as each other
#
# ...
